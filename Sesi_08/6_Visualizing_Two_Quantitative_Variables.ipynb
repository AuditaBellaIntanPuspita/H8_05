# %%
# Import the matplotlib.pyplot, pandas, and numpy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\SEMESTER 4\Github\H8_05\Sesi8\6_Visualizing_Two_Quantitative_Variables.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import files
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
student_data = pd.read_csv('student-alcohol-consumption.csv')
student_data.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Creating subplots with col and row
#
# 1. Modify the code to use relplot() instead of scatterplot().
# 2. Modify the code to create one scatter plot for each level of the variable "study_time", arranged in columns.
# 3. Adapt your code to create one scatter plot for each level of a student's weekly study time, this time arranged in rows.
#
# **HINT!**
#
# * Use relplot() and set the kind parameter.
# * Use the col parameter to create subplots arranged in columns.
# * Use the row parameter to arrange the scatter plots in rows.

# %%
# Change to use relplot() instead of scatterplot() and make this fit as instruction
sns.relplot(x="absences", y="G3", 
                data=student_data,
                kind="scatter",
                col="study_time",
                row="study_time")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1759, in categorical_order(vector, order)
#    1758 try:
# -> 1759     order = vector.cat.categories
#    1760 except (TypeError, AttributeError):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1763, in categorical_order(vector, order)
#    1762 try:
# -> 1763     order = vector.unique()
#    1764 except AttributeError:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# d:\SEMESTER 4\Github\H8_05\Sesi8\6_Visualizing_Two_Quantitative_Variables.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Change to use relplot() instead of scatterplot() and make this fit as instruction
# ----> <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> sns.relplot(x="absences", y="G3",
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>                 data=student_data,
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>                 kind="scatter",
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>                 col="study_time",
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>                 row="study_time")
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> # Show plot
#       <a href='vscode-notebook-cell:/d%3A/SEMESTER%204/Github/H8_05/Sesi8/6_Visualizing_Two_Quantitative_Variables.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> plt.show()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:946, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     944 # Set up the FacetGrid object
#     945 facet_kws = {} if facet_kws is None else facet_kws.copy()
# --> 946 g = FacetGrid(
#     947     data=full_data.dropna(axis=1, how="all"),
#     948     **grid_kws,
#     949     col_wrap=col_wrap, row_order=row_order, col_order=col_order,
#     950     height=height, aspect=aspect, dropna=False,
#     951     **facet_kws
#     952 )
#     954 # Draw the plot
#     955 g.map_dataframe(func, **plot_kws)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:391, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     389     row_names = []
#     390 else:
# --> 391     row_names = categorical_order(data[row], row_order)
#     393 if col is None:
#     394     col_names = []
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765, in categorical_order(vector, order)
#    1763     order = vector.unique()
#    1764 except AttributeError:
# -> 1765     order = pd.unique(vector)
#    1767 if variable_type(vector) == "numeric":
#    1768     order = np.sort(order)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:409, in unique(values)
#     315 def unique(values):
#     316     """
#     317     Return unique values based on a hash table.
#     318
#    (...)
#     407     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     408     """
# --> 409     return unique_with_mask(values)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:414, in unique_with_mask(values, mask)
#     412 def unique_with_mask(values, mask: npt.NDArray[np.bool_] | None = None):
#     413     """See algorithms.unique for docs. Takes a mask for masked arrays."""
# --> 414     values = _ensure_arraylike(values)
#     416     if is_extension_array_dtype(values.dtype):
#     417         # Dispatch to extension dtype's unique.
#     418         return values.unique()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:245, in _ensure_arraylike(values)
#     243     if isinstance(values, tuple):
#     244         values = list(values)
# --> 245     values = construct_1d_object_array_from_listlike(values)
#     246 else:
#     247     values = np.asarray(values)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1784, in construct_1d_object_array_from_listlike(values)
#    1781 # numpy will try to interpret nested lists as further dimensions, hence
#    1782 # making a 1D array that contains list-likes is a bit tricky:
#    1783 result = np.empty(len(values), dtype="object")
# -> 1784 result[:] = values
#    1785 return result
#
# ValueError: could not broadcast input array from shape (395,2) into shape (395,)

# %% [markdown]
# ## Creating two-factor subplots
#
# 1. Use relplot() to create a scatter plot with "G1" on the x-axis and "G3" on the y-axis, using the student_data DataFrame.
# 2. Create column subplots based on whether the student received support from the school ("schoolsup"), ordered so that "yes" comes before "no".
# 3. Add row subplots based on whether the student received support from the family ("famsup"), ordered so that "yes" comes before "no". This will result in subplots based on two factors.
#
# **HINT!**
#
# * Use the col and col_order parameters.
# * Use the row and row_order parameters.

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])

# %% [markdown]
# ## Changing the size of scatter plot points
#
# 1. Use relplot() and the mpg DataFrame to create a scatter plot with "horsepower" on the x-axis and "mpg" on the y-axis. Vary the size of the points by the number of cylinders in the car ("cylinders").
# 2. To make this plot easier to read, use hue to vary the color of the points by the number of cylinders in the car ("cylinders").
#
# **HINT!**
#
# * Use the size parameter to vary the point size based on number of cylinders.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb890725-99bf-49b3-91a1-454e9ae208ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb890725-99bf-49b3-91a1-454e9ae208ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mpg.csv to mpg.csv

# %%
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders", hue="cylinders")



# Show plot
plt.show()

# %% [markdown]
# ## Changing the style of scatter plot points
#
# Use relplot() and the mpg DataFrame to create a scatter plot with "acceleration" on the x-axis and "mpg" on the y-axis. Vary the style and color of the plot points by country of origin ("origin").
#
# **HINT!**
#
# Use the style and hue parameters to vary the style and color of the points based on country of origin.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of acceleration vs. mpg
sns.relplot(x="acceleration", y="mpg", 
            data=mpg, kind="scatter", 
            style="origin", hue="origin")



# Show plot
plt.show()

# %% [markdown]
# ## Interpreting line plots
#
# 1. Use relplot() and the mpg DataFrame to create a line plot with "model_year" on the x-axis and "mpg" on the y-axis.
#
# **HINT!**
#
# * Specify the type of plot using the kind parameter.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create line plot
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line")


# Show plot
plt.show()

# %% [markdown]
# ## Visualizing standard deviation with line plots
#
# Change the plot so the shaded area shows the standard deviation instead of the confidence interval for the mean.
#
# **HINT!**
#
# Use the ci parameter to change what the shaded area represents.

# %%
# Make the shaded area show the standard deviation
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line",
            ci="sd")

# Show plot
plt.show()

# %% [markdown]
# ## Plotting subgroups in line plots
#
# 1. Use relplot() and the mpg DataFrame to create a line plot with "model_year" on the x-axis and "horsepower" on the y-axis. Turn off the confidence intervals on the plot.
# 2. Create different lines for each country of origin ("origin") that vary in both line style and color.
# 3. Add markers for each data point to the lines.
# 4. Use the dashes parameter to use solid lines for all countries, while still allowing for different marker styles for each line.
#
# **HINT!**
#
# * Use the markers parameter to turn on showing markers on the lines.
# * Use the dashes parameter to turn off having different line styles per line.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Change to create subgroups for country of origin
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, , style="origin", 
            hue="origin")

# Show plot
plt.show()
